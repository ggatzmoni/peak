# %%
import pandas as pd

# %%
df_songs = pd.read_csv("../data/data.csv")
df_genre = pd.read_csv("../data/data_w_genres.csv")

# %%
df_songs
# Out:
#         acousticness                                            artists  \
# 0             0.9950                                ['Carl Woitschach']
# 1             0.9940           ['Robert Schumann', 'Vladimir Horowitz']
# 2             0.6040                            ['Seweryn Goszczyński']
# 3             0.9950                               ['Francisco Canaro']
# 4             0.9900           ['Frédéric Chopin', 'Vladimir Horowitz']
# 5             0.9950         ['Felix Mendelssohn', 'Vladimir Horowitz']
# 6             0.9560               ['Franz Liszt', 'Vladimir Horowitz']
# 7             0.9880                                ['Carl Woitschach']
# 8             0.9950                     ['Francisco Canaro', 'Charlo']
# 9             0.8460                            ['Seweryn Goszczyński']
# 10            0.9940       ['Sergei Rachmaninoff', 'Vladimir Horowitz']
# 11            0.9890           ['Frédéric Chopin', 'Vladimir Horowitz']
# ...

# %%
df_genre
# Out:
#                                                  artists  acousticness  \
# 0                       "Cats" 1981 Original London Cast      0.575083
# 1                              "Cats" 1983 Broadway Cast      0.862538
# 2            "Fiddler On The Roof” Motion Picture Chorus      0.856571
# 3         "Fiddler On The Roof” Motion Picture Orchestra      0.884926
# 4      "Joseph And The Amazing Technicolor Dreamcoat"...      0.605444
# 5      "Joseph And The Amazing Technicolor Dreamcoat"...      0.609556
# 6                                 "Mama" Helen Teagarden      0.725000
# 7                                         "Mista Dj Paul      0.006900
# 8                                "Test for Victor Young"      0.927000
# 9                                    "Weird Al" Yankovic      0.176934
# 10                                                $IMEON      0.242300
# 11                                                  $NOT      0.547000
# ...
